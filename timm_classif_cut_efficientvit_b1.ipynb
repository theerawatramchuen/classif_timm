# %%
import os
import time
import torch
import timm
import numpy as np
import matplotlib.pyplot as plt
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split
from sklearn.model_selection import train_test_split
from datetime import datetime
from PIL import Image

# %%
# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = "cpu"

# Custom dataset folder
#dataset_path = 'F:/vit_custom_img_classif/key_desc_org'  # Update this path
dataset_path = 'dataset_cut'

# %%
# Preset values
dropout_rate = 0.0
batch_size = 1
learning_rate = 1e-4
num_epochs = 40
image_size = 513

# %%
# Data augmentation and normalization for training
transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.RandomHorizontalFlip(),
    #transforms.RandomRotation(degrees=(0, 360)),
    #transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5),
    #transforms.RandomResizedCrop(size=image_size),
    #transforms.RandomPerspective(distortion_scale=0.5, probability=0.5),
    transforms.RandomVerticalFlip(),
    #transforms.GaussianBlur(kernel_size=(5, 9), sigma=(0.1, 5)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    transforms.RandomErasing(p=0.0),
])

# %%
# Load custom dataset
dataset = datasets.ImageFolder(dataset_path, transform=transform)
class_names = dataset.classes
num_classes = len(class_names)

# %%
# Split dataset into training and validation sets
train_size = int(0.7 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# %%
# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)

# %%
# List of Vit Models with Pretrained Weight
all_models = timm.list_models('eff*v*')
all_models
# Out:
# ['efficientformerv2_l',
#  'efficientformerv2_s0',
#  'efficientformerv2_s1',
#  'efficientformerv2_s2',
#  'efficientnet_b0_g16_evos',
#  'efficientnetv2_l',
#  'efficientnetv2_m',
#  'efficientnetv2_rw_m',
#  'efficientnetv2_rw_s',
#  'efficientnetv2_rw_t',
#  'efficientnetv2_s',
#  'efficientnetv2_xl',
#  'efficientvit_b0',
#  'efficientvit_b1',
#  'efficientvit_b2',
#  'efficientvit_b3',
#  'efficientvit_l1',
#  'efficientvit_l2',
#  'efficientvit_l3',
#  'efficientvit_m0',
#  'efficientvit_m1',
#  'efficientvit_m2',
#  'efficientvit_m3',
#  'efficientvit_m4',
#  'efficientvit_m5']

# %%
mypretrainedname = 'efficientvit_b1' #Put one of the model name listed in previous cell

# %%
# Load pre-trained ViT model with specified dropout rate
model = timm.create_model(mypretrainedname, pretrained=True, num_classes=num_classes, drop_rate=dropout_rate)
model = model.to(device)

# %%
# Loss function and optimizer
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
# Summary info before training loop
print(f"Custom dataset folder: {dataset_path}")
print(f"Number of classes: {num_classes} with class names: {class_names}")
print(f"Preset dropout rate: {dropout_rate}")
print(f"Training/Testing Ratio: {train_size}/{val_size}")
print(f"Learning rate: {learning_rate}")
# Out:
# Custom dataset folder: dataset_cut
# Number of classes: 2 with class names: ['Bad', 'Good']
# Preset dropout rate: 0.0
# Training/Testing Ratio: 228/98
# Learning rate: 0.0001

# %%
# Training and validation
train_acc_history, val_acc_history = [], []
train_loss_history, val_loss_history = [], []

# %%
# Continue training start here
start_time = time.time()  # Start time of the training

for epoch in range(num_epochs):
    epoch_start_time = time.time()  # Start time of the current epoch

    # [Your existing training and validation code goes here]

    # Calculate average losses and accuracy
    # [Your existing code for calculating and storing training/validation losses and accuracies]
    # Training
    model.train()
    train_loss, train_correct = 0.0, 0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * inputs.size(0)
        _, predictions = torch.max(outputs, 1)
        train_correct += torch.sum(predictions == labels.data)
    
    # Validation
    model.eval()
    val_loss, val_correct = 0.0, 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item() * inputs.size(0)
            _, predictions = torch.max(outputs, 1)
            val_correct += torch.sum(predictions == labels.data)
    
    # Calculate average losses and accuracy
    train_loss = train_loss / train_size
    train_acc = train_correct.double() / train_size
    val_loss = val_loss / val_size
    val_acc = val_correct.double() / val_size

    # Save history for plotting
    train_acc_history.append(train_acc.cpu().numpy())
    train_loss_history.append(train_loss)
    val_acc_history.append(val_acc.cpu().numpy())
    val_loss_history.append(val_loss)

    
    epoch_time = time.time() - epoch_start_time  # Time taken for the current epoch
    total_time = time.time() - start_time  # Total time elapsed since the start of training
    avg_time_per_epoch = total_time / (epoch + 1)  # Average time per epoch
    remaining_epochs = num_epochs - epoch - 1
    estimated_remaining_time = avg_time_per_epoch * remaining_epochs

    # Convert estimated remaining time from seconds to minutes
    estimated_remaining_time_min = estimated_remaining_time / 60

    # Print results every epoch with estimated remaining time
    print(f"Epoch {epoch+1}/{num_epochs}.. "
          f"Train loss: {train_loss:.4f}.. "
          f"Train accuracy: {train_acc:.4f}.. "
          f"Val loss: {val_loss:.4f}.. "
          f"Val accuracy: {val_acc:.4f}.. "
          f"Remaining time: {estimated_remaining_time_min:.2f} minutes")
# Out:
# Epoch 1/40.. Train loss: 0.3754.. Train accuracy: 0.8377.. Val loss: 0.4335.. Val accuracy: 0.9184.. Remaining time: 12.83 minutes
# Epoch 2/40.. Train loss: 0.1183.. Train accuracy: 0.9518.. Val loss: 0.0597.. Val accuracy: 1.0000.. Remaining time: 11.59 minutes
# Epoch 3/40.. Train loss: 0.0484.. Train accuracy: 0.9825.. Val loss: 0.1250.. Val accuracy: 0.9694.. Remaining time: 10.98 minutes
# Epoch 4/40.. Train loss: 0.0150.. Train accuracy: 1.0000.. Val loss: 0.0168.. Val accuracy: 1.0000.. Remaining time: 10.55 minutes
# Epoch 5/40.. Train loss: 0.0003.. Train accuracy: 1.0000.. Val loss: 0.0146.. Val accuracy: 1.0000.. Remaining time: 10.17 minutes
# Epoch 6/40.. Train loss: 0.0002.. Train accuracy: 1.0000.. Val loss: 0.0165.. Val accuracy: 1.0000.. Remaining time: 9.82 minutes
# Epoch 7/40.. Train loss: 0.0001.. Train accuracy: 1.0000.. Val loss: 0.0116.. Val accuracy: 1.0000.. Remaining time: 9.53 minutes
# Epoch 8/40.. Train loss: 0.0001.. Train accuracy: 1.0000.. Val loss: 0.0128.. Val accuracy: 1.0000.. Remaining time: 9.27 minutes
# Epoch 9/40.. Train loss: 0.0001.. Train accuracy: 1.0000.. Val loss: 0.0105.. Val accuracy: 1.0000.. Remaining time: 8.98 minutes
# Epoch 10/40.. Train loss: 0.0001.. Train accuracy: 1.0000.. Val loss: 0.0104.. Val accuracy: 1.0000.. Remaining time: 8.67 minutes
# Epoch 11/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0088.. Val accuracy: 1.0000.. Remaining time: 8.37 minutes
# Epoch 12/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0114.. Val accuracy: 1.0000.. Remaining time: 8.07 minutes
# Epoch 13/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0070.. Val accuracy: 1.0000.. Remaining time: 7.77 minutes
# Epoch 14/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0124.. Val accuracy: 1.0000.. Remaining time: 7.48 minutes
# Epoch 15/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0078.. Val accuracy: 1.0000.. Remaining time: 7.18 minutes
# Epoch 16/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0122.. Val accuracy: 1.0000.. Remaining time: 6.89 minutes
# Epoch 17/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0106.. Val accuracy: 1.0000.. Remaining time: 6.60 minutes
# Epoch 18/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0065.. Val accuracy: 1.0000.. Remaining time: 6.31 minutes
# Epoch 19/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0048.. Val accuracy: 1.0000.. Remaining time: 6.02 minutes
# Epoch 20/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0152.. Val accuracy: 0.9898.. Remaining time: 5.73 minutes
# Epoch 21/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0067.. Val accuracy: 1.0000.. Remaining time: 5.44 minutes
# Epoch 22/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0079.. Val accuracy: 1.0000.. Remaining time: 5.15 minutes
# Epoch 23/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0126.. Val accuracy: 1.0000.. Remaining time: 4.86 minutes
# Epoch 24/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0067.. Val accuracy: 1.0000.. Remaining time: 4.57 minutes
# Epoch 25/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0032.. Val accuracy: 1.0000.. Remaining time: 4.29 minutes
# Epoch 26/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0070.. Val accuracy: 1.0000.. Remaining time: 4.00 minutes
# Epoch 27/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0081.. Val accuracy: 1.0000.. Remaining time: 3.71 minutes
# Epoch 28/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0043.. Val accuracy: 1.0000.. Remaining time: 3.43 minutes
# Epoch 29/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0070.. Val accuracy: 1.0000.. Remaining time: 3.14 minutes
# Epoch 30/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0097.. Val accuracy: 1.0000.. Remaining time: 2.85 minutes
# Epoch 31/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0053.. Val accuracy: 1.0000.. Remaining time: 2.57 minutes
# Epoch 32/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0060.. Val accuracy: 1.0000.. Remaining time: 2.28 minutes
# Epoch 33/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0071.. Val accuracy: 1.0000.. Remaining time: 2.00 minutes
# Epoch 34/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0065.. Val accuracy: 1.0000.. Remaining time: 1.71 minutes
# Epoch 35/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0081.. Val accuracy: 1.0000.. Remaining time: 1.43 minutes
# Epoch 36/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0047.. Val accuracy: 1.0000.. Remaining time: 1.14 minutes
# Epoch 37/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0032.. Val accuracy: 1.0000.. Remaining time: 0.86 minutes
# Epoch 38/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0068.. Val accuracy: 1.0000.. Remaining time: 0.57 minutes
# Epoch 39/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0039.. Val accuracy: 1.0000.. Remaining time: 0.29 minutes
# Epoch 40/40.. Train loss: 0.0000.. Train accuracy: 1.0000.. Val loss: 0.0042.. Val accuracy: 1.0000.. Remaining time: 0.00 minutes

# %%
# Plot trend chart for Accuracy and Loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_acc_history, label='Training Accuracy')
plt.plot(val_acc_history, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.subplot(1, 2, 2)
plt.plot(train_loss_history, label='Training Loss')
plt.plot(val_loss_history, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Save the model
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
model_save_path = os.path.join(dataset_path, mypretrainedname + f'_{timestamp}.pth')
torch.save(model.state_dict(), model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Model saved to dataset_cut\efficientvit_b1_20240305_153303.pth

# %%
# Predict Function
def predict_image(image_path, model, device, transform, class_names):
    image = Image.open(image_path).convert('RGB')
    inputs = transform(image).unsqueeze(0).to(device)
    model.eval()
    with torch.no_grad():
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        confidence = torch.nn.functional.softmax(outputs, dim=1)[0] * 100
    _, predicted_confidence = torch.max(confidence, 0)
    
    plt.imshow(image)
    plt.title(f"{class_names[predicted]} ({confidence[predicted].item():.2f}%)") #({confidence[predicted]:.2f}%)
    plt.show()

# %%
# Load the model weights 
# filename = model_save_path
filename = dataset_path + "/" + "efficientvit_b1_20240305_080734.pth"

loaded_weights = torch.load(filename)

# load the weights 
model.load_state_dict(loaded_weights)
# Out:
# <All keys matched successfully>

# %%
print (class_names)
# Out:
# ['Bad', 'Good']

# %%
# Your existing predict_image function
def predict_image(image_path, model, device, transform, class_names):
    image = Image.open(image_path).convert('RGB')
    inputs = transform(image).unsqueeze(0).to(device)
    model.eval()
    with torch.no_grad():
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        confidence = torch.nn.functional.softmax(outputs, dim=1)[0] * 100
    return class_names[predicted[0]], confidence[predicted[0]].item(), image

# %%
from tqdm.notebook import tqdm  # Use tqdm.notebook.tqdm for Jupyter Notebook

def process_folders(image_folder_path, model, device, transform, class_names):
    total_images = 0
    misclassified_images = 0
    total_prediction_time = 0
    
    # Get the list of class folders
    class_folders = [f for f in os.listdir(image_folder_path) if os.path.isdir(os.path.join(image_folder_path, f))]
    
    # Wrap the loop with tqdm for the progress bar
    for class_folder in tqdm(class_folders, desc='Processing folders'):
        folder_path = os.path.join(image_folder_path, class_folder)
        
        # Get the list of image files
        image_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
        
        # Wrap the loop with tqdm for the progress bar
        for image_file in tqdm(image_files, desc=f'Processing {class_folder}', leave=False):
            total_images += 1
            image_path = os.path.join(folder_path, image_file)
            
            start_time = time.time()
            predicted_label, confidence, image = predict_image(image_path, model, device, transform, class_names)
            prediction_time = time.time() - start_time
            total_prediction_time += prediction_time

            # Count and show image if misclassified
            if predicted_label != class_folder:
                misclassified_images += 1
                plt.imshow(image)
                plt.title(f"Predicted: {predicted_label} ({confidence:.2f}%), Actual: {class_folder}")
                plt.show()

    # Calculate and display results
    if total_images > 0:
        misclassification_percentage = (misclassified_images / total_images) * 100
        average_prediction_time = total_prediction_time / total_images
        print(f"Total Images: {total_images}")
        print(f"Misclassified Images: {misclassified_images}")
        print(f"Misclassification Percentage: {misclassification_percentage:.2f}%")
        print(f"Average Prediction Time per Image: {average_prediction_time:.4f} seconds")
    else:
        print("No images found in the provided folder.")

# Example usage:
# process_folders('path_to_image_folder', model, device, transform, class_names)

# %%
# Example usage
image_folder_path = dataset_path #'path_to_your_image_folder'
# model, device, transform, and class_names need to be defined as per your model and dataset
process_folders(image_folder_path, model, device, transform, class_names)
# Out:
# Processing folders:   0%|          | 0/2 [00:00<?, ?it/s]
# Processing Bad:   0%|          | 0/218 [00:00<?, ?it/s]
# Processing Good:   0%|          | 0/108 [00:00<?, ?it/s]
# Total Images: 326
# Misclassified Images: 1
# Misclassification Percentage: 0.31%
# Average Prediction Time per Image: 0.0249 seconds
